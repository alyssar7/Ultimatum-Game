# %% [markdown]
# ## Structural Estimation of the Ultimatum Game Parameters

# %%
import Pkg
Pkg.add("Distributions")
Pkg.add("BlackBoxOptim")
Pkg.add("ForwardDiff")
Pkg.add("Optim")
Pkg.add("HTTP")
Pkg.add("DataFrames")
Pkg.add("Pandas")
Pkg.add("Plots")
# Out:
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.7/Project.toml`
#   No Changes to `~/.julia/environments/v1.7/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.7/Project.toml`
#   No Changes to `~/.julia/environments/v1.7/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.7/Project.toml`
#   No Changes to `~/.julia/environments/v1.7/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.7/Project.toml`
#   No Changes to `~/.julia/environments/v1.7/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.7/Project.toml`
#   No Changes to `~/.julia/environments/v1.7/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.7/Project.toml`
#   No Changes to `~/.julia/environments/v1.7/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.7/Project.toml`
#   No Changes to `~/.julia/environments/v1.7/Manifest.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.7/Project.toml`
#   No Changes to `~/.julia/environments/v1.7/Manifest.toml`

# %%
using Distributions, BlackBoxOptim, ForwardDiff, Optim, HTTP, DataFrames, Pandas, Plots

# %%
data = read_csv("datamerged2.csv")
# Out:
#        id  treatment  tofrom  value  role  resp  round  rounds  old
# 0       1          1       6   20.0     0     1      1       2    0
# 1       1          1       9   20.0     0     0      1       2    0
# 2       1          1      10   20.0     0     1      1       2    0
# 3       1          1      11   20.0     0     1      1       2    0
# 4       1          1      13   20.0     0     1      1       2    0
# ...   ...        ...     ...    ...   ...   ...    ...     ...  ...
# 2088  271          4     277   25.0     0     1      2       2    2
# 2089  271          4     278   30.0     0     1      2       2    2
# 2090  271          4     279   25.0     0     1      2       2    2
# 2091  271          4     280   30.0     0     1      2       2    2
# 2092  271          4     281   25.0     0     1      2       2    2
#
# [2093 rows x 9 columns]

# %%
#parameters
alph = 1 #competitiveness term
r = 5 #reference offer #close to the minimum offer observed in the data
# Out:
# 5

# %%
#offers
s = data.value
# Out:
# 0       20.0
# 1       20.0
# 2       20.0
# 3       20.0
# 4       20.0
#         ...
# 2088    25.0
# 2089    30.0
# 2090    25.0
# 2091    30.0
# 2092    25.0
# Name: value, Length: 2093, dtype: float64

# %%
#summary stats of the distribution of offers
mu = (mean(s))
sigma = std(s)
# Out:
# 7.226530390628302

# %%
#guess the distribution of offers as a truncated normal
Q = TruncatedNormal(mu, sigma, 0, 55)
# Out:
# Truncated(Normal{Float64}(μ=18.792202582156044, σ=7.226530390628302), range=(0.0, 55.0))

# %%
#generate the probability of seeing a given offer 's' (PDF)
pdfValues = zeros(0)
for i in s
    append!(pdfValues, pdf(Q, i))
end

# %%
#generate the probability of seeing an offer *less* than a given offer 's' (CDF)
cdfValues = zeros(0)
for i in s
    append!(cdfValues, cdf(Q, i))
end

# %%
#loss aversion parameters
lambda = 2*cdfValues*(1 + 2*alph)./pdfValues - 2*(1 - s*(1 + 2*alph)) + 1
mean(lambda)
# Out:
# 836.6382129419785
